# %% [markdown]
# # Assignment 1: Question 3

# %% [markdown]
# Consider the _company_sales.csv_ dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sales = pd.read_csv("company_sales.csv")

# %% [markdown]
# An investor would like to decide on a company to invest in. The _company_sales.csv_ dataset contains the sales (in millions) over a selected time period for the 3 companies under consideration.

# %% [markdown]
# 1. Retrieve the first 5 rows of the data to see how it is structured.

# %%
sales.head()
# Out:
#    Period  Nexus Innovations  Quantum Industries  StellarTech Solutions
# 0       1           2.789186            6.711266               6.256332
# 1       2           3.604428            5.080032               6.292007
# 2       3           3.053541            6.940776               6.427880
# 3       4           2.769928            7.848754               6.712436
# 4       5           2.175909            4.995013               6.875492

# %% [markdown]
# 2. Plot a line graph showing the sales over a time for the 3 companies in a single plot. Remember to label and format the graph appropriately to create an effective and meaningful visualisation.
#
# Some specifications:
# - Include a legend in the top left corner.
# - Use a black dashed line for the Nexus Innovations data
# - Use a red solid line for the Quantum Industries data
# - Use an orange dash-dot line for the StellarTech Solutions data

# %%
nex = sales["Nexus Innovations"]
quan = sales["Quantum Industries"]
st = sales["StellarTech Solutions"]

fig = plt.figure()
ax = plt.axes()

plt.plot(nex, '--', color='black', label = 'Nexus Innovations')
plt.plot(quan, '-', color='red', label = 'Quantum Industries')
plt.plot(st, '-.', color='orange', label = 'StellarTech Solutions')
plt.xlim(-1, 110)


plt.title("Sales of 3 companies over time")
plt.xlabel("Period of time")
plt.ylabel("Sales (in millions)");
plt.grid()
plt.legend(loc='upper left', frameon=False)

# %% [markdown]
# 3. Based on the plot, which company would you recommend to the investor to invest in and why?

# %% [markdown]
# ## I would invest in StellarTech Solutions as the graph clearly shows that it has increased its sales over the period of time.

# %% [markdown]
# <h3><center>End of Question 3</center></h3>
